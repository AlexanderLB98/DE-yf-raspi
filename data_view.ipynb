# %%
import pandas as pd

# %%
df = pd.read_csv("test_file.csv", header=[0, 1])
df
# Out:
#   Unnamed: 0_level_0 level_0 index        Date  Ticker              ^AEX  \
#                    0       0     0  2025-01-31   Close 921.9400024414062
# 0                  1       1     1  2025-01-31    High      9.278000e+02
# 1                  2       2     2  2025-01-31     Low      9.210200e+02
# 2                  3       3     3  2025-01-31    Open      9.218600e+02
# 3                  4       4     4  2025-01-31  Volume      5.959880e+07
# 4                  5       0     0  2025-01-31   Close               NaN
# 5                  6       1     1  2025-01-31    High               NaN
# 6                  7       2     2  2025-01-31     Low               NaN
# 7                  8       3     3  2025-01-31    Open               NaN
# 8                  9       4     4  2025-01-31  Volume               NaN
#
#   company_code               NVDA
#           ^AEX Unnamed: 7_level_1
# 0         ^AEX                NaN
# 1         ^AEX                NaN
# ...
